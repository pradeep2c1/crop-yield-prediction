# %%
import geopandas as gpd

# %%
# !pip install geopandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 14.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 74.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 87.0 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## Open file_name Method
# // Not to be used

# %%
file_name = '/content/output.shp'

# %%
file = open(file_name)

# %%
gdf = gpd.read_file(file)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-8-3c69bd74823f> in <cell line: 1>()
# ----> 1 gdf = gpd.read_file(file)
#
# /usr/local/lib/python3.9/dist-packages/geopandas/io/file.py in _read_file(filename, bbox, mask, rows, engine, **kwargs)
#     250         from_bytes = True
#     251     elif pd.api.types.is_file_like(filename):
# --> 252         data = filename.read()
#     253         path_or_bytes = data.encode("utf-8") if isinstance(data, str) else data
#     254         from_bytes = True
#
# /usr/lib/python3.9/codecs.py in decode(self, input, final)
#     320         # decode input (taking the buffer into account)
#     321         data = self.buffer + input
# --> 322         (result, consumed) = self._buffer_decode(data, self.errors, final)
#     323         # keep undecoded input until the next call
#     324         self.buffer = data[consumed:]
#
# ...

# %% [markdown]
# ## >>

# %%
gdf = gpd.read_file('/content/output.shp')

# %%
gdf
# Out:
#      objectid statecode    statename state_ut distcode      distname  \
# 0           1        05  Uttarakhand    STATE      066      Nainital
# 1           2        05  Uttarakhand    STATE      060      Dehradun
# 2           3        05  Uttarakhand    STATE      064        Almora
# 3           4        05  Uttarakhand    STATE      065     Champawat
# 4           5        05  Uttarakhand    STATE      056    Uttarkashi
# ..        ...       ...          ...      ...      ...           ...
# 688       691        36    Telangana    STATE      T28    Wanaparthy
# 689       692        36    Telangana    STATE      T27     Vikarabad
# 690       693        36    Telangana    STATE      T13  Mahabubnagar
# 691        41        01       Ladakh    STATE      004        Kargil
# 692        34        01       Ladakh    STATE      003  Leh (Ladakh)
#
#      distarea  totalpopul   totalhh  totpopmale  totpopfema    st_areasha  \
# ...

# %%
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots(figsize=(6, 6))
gdf.plot(ax=ax)
plt.show()

# %%
statename = 'Uttar Pradesh'
my = gdf[gdf.statename == statename]

# %%
my
# Out:
#      objectid statecode      statename state_ut distcode  \
# 78        604        09  Uttar Pradesh    STATE      178
# 79        605        09  Uttar Pradesh    STATE      193
# 80        606        09  Uttar Pradesh    STATE      164
# 81        607        09  Uttar Pradesh    STATE      198
# 243       608        09  Uttar Pradesh    STATE      184
# ..        ...       ...            ...      ...      ...
# 642       615        09  Uttar Pradesh    STATE      168
# 643       616        09  Uttar Pradesh    STATE      183
# 644       617        09  Uttar Pradesh    STATE      163
# 645       618        09  Uttar Pradesh    STATE      194
# 653       656        09  Uttar Pradesh    STATE      175
#
#                          distname  distarea  totalpopul   totalhh  totpopmale  \
# 78                 Ambedkar Nagar    2350.0   2397888.0  368728.0   1212410.0
# 79                         Ballia    2981.0   3239774.0  480268.0   1672902.0
# ...

# %%
fig, ax = plt.subplots(figsize=(5, 5))
my.plot(ax=ax)
plt.show()

# %%
adf = my[my.distname=='Agra']

# %%
adf
# Out:
#      objectid statecode      statename state_ut distcode distname  distarea  \
# 372       635        09  Uttar Pradesh    STATE      146     Agra    4041.0
#
#      totalpopul   totalhh  totpopmale  totpopfema    st_areasha  \
# 372   4418797.0  710566.0   2364953.0   2053844.0  5.103217e+09
#
#         st_lengths                                           geometry
# 372  797837.435904  POLYGON ((77.87337 26.90196, 77.87271 26.90217...

# %%
a_shape = adf.geometry

# %%
a_shape
# Out:
# 372    POLYGON ((77.87337 26.90196, 77.87271 26.90217...
# Name: geometry, dtype: geometry

# %%
import pandas as pd

# %%
dist_list = pd.Series(my['distname'])

# %%
pd.set_option('display.max_columns', None)

# %%
dist_list
# Out:
# 78                   Ambedkar Nagar
# 79                           Ballia
# 80                     Kanpur Nagar
# 81     Sant Ravidas Nagar (Bhadohi)
# 243                  Siddharthnagar
#                    ...
# 642                        Hamirpur
# 643                           Gonda
# 644                    Kanpur Dehat
# 645                         Jaunpur
# 653                       Allahabad
# Name: distname, Length: 75, dtype: object

# %%
dd = pd.DataFrame(dist_list)

# %%
dd

# %%
dd.sort_values(by=['distname'])
# Out:
#            distname
# 372            Agra
# 631         Aligarh
# 653       Allahabad
# 78   Ambedkar Nagar
# 366          Amethi
# ..              ...
# 581         Sitapur
# 438       Sonbhadra
# 621       Sultanpur
# 362           Unnao
# 340        Varanasi
#
# [75 rows x 1 columns]

# %%
print(dist_list)
# Out:
# 78                   Ambedkar Nagar
# 79                           Ballia
# 80                     Kanpur Nagar
# 81     Sant Ravidas Nagar (Bhadohi)
# 243                  Siddharthnagar
#                    ...
# 642                        Hamirpur
# 643                           Gonda
# 644                    Kanpur Dehat
# 645                         Jaunpur
# 653                       Allahabad
# Name: distname, Length: 75, dtype: object

# %% [markdown]
# ## Crop Data

# %%
cr = pd.read_excel('/content/Agra_moong.xls')

# %%
cr = cr.T

# %%
cr
# Out:
#                              0                       1              2   \
# Crop Production Statistics  NaN     State/Crop/District  Uttar Pradesh
# Unnamed: 1                  NaN                    Year            NaN
# Unnamed: 2                  NaN                  Season            NaN
# Unnamed: 3                  NaN          Area (Hectare)            NaN
# Unnamed: 4                  NaN     Production (Tonnes)            NaN
# Unnamed: 5                  NaN  Yield (Tonnes/Hectare)            NaN
#
#                                            3            4            5   \
# Crop Production Statistics  Moong(Green Gram)       1.AGRA          NaN
# Unnamed: 1                                NaN      1997-98      1998-99
# Unnamed: 2                                NaN  Summer       Summer
# Unnamed: 3                                NaN          770          469
# Unnamed: 4                                NaN          269          231
# ...

# %%
cr.drop(['Unnamed: 2'])
cr.drop(columns=[0, 2, 3])
# Out:
#                                                 1            4            5   \
# Crop Production Statistics     State/Crop/District       1.AGRA          NaN
# Unnamed: 1                                    Year      1997-98      1998-99
# Unnamed: 2                                  Season  Summer       Summer
# Unnamed: 3                          Area (Hectare)          770          469
# Unnamed: 4                     Production (Tonnes)          269          231
# Unnamed: 5                  Yield (Tonnes/Hectare)     0.349351     0.492537
#
#                                      6            7            8   \
# Crop Production Statistics          NaN          NaN          NaN
# Unnamed: 1                      1999-00      2002-03      2003-04
# Unnamed: 2                  Summer       Summer       Summer
# Unnamed: 3                          239           74           63
# Unnamed: 4                           98           35           25
# ...

# %%
cr = cr.T

# %%
cr
# Out:
#    Crop Production Statistics Unnamed: 1   Unnamed: 2      Unnamed: 3  \
# 0                         NaN        NaN          NaN             NaN
# 1         State/Crop/District       Year       Season  Area (Hectare)
# 2               Uttar Pradesh        NaN          NaN             NaN
# 3           Moong(Green Gram)        NaN          NaN             NaN
# 4                      1.AGRA    1997-98  Summer                  770
# 5                         NaN    1998-99  Summer                  469
# 6                         NaN    1999-00  Summer                  239
# 7                         NaN    2002-03  Summer                   74
# 8                         NaN    2003-04  Summer                   63
# 9                         NaN    2007-08  Summer                   57
# 10                        NaN    2008-09  Summer                   51
# 11                        NaN    2009-10  Summer                  161
# ...

# %% [markdown]
# ## IMDLIB Data

# %%
# conda install -c iamsaswata imdlib
# !pip install imdlib
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import imdlib as imd

# %%
## DOESN'T WORK for OLDER DATES
start_dy = '1997-04-01'
end_dy = '1997-05-31'
var_type = 'rain'
data = imd.get_real_data(var_type, start_dy, end_dy)
# Out:
# Downloading: rain for date 1997-04-01
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-17-ee4768e61152> in <cell line: 5>()
#       3 end_dy = '1997-05-31'
#       4 var_type = 'rain'
# ----> 5 data = imd.get_real_data(var_type, start_dy, end_dy)
#
# /usr/local/lib/python3.10/dist-packages/imdlib/real.py in get_real_data(var_type, start_dy, end_dy, file_dir, proxies)
#     206
#     207             if len(response.content) < 1:
# --> 208                 raise Exception("Error in file download. \nData not downloaded for date : {}. \nStopping IMDLIB".format(str(day.date())))
#     209                 return data
#     210
#
# Exception: Error in file download.
# Data not downloaded for date : 1997-04-01.
# Stopping IMDLIB

# %%
start_yr = 1997
end_yr = 2019
variable = 'rain' # other options are ('tmin'/ 'tmax')
data = imd.get_data(variable, start_yr, end_yr, fn_format='yearwise')
# Out:
# Downloading: rain for year 1997
# Downloading: rain for year 1998
# Downloading: rain for year 1999
# Downloading: rain for year 2000
# Downloading: rain for year 2001
# Downloading: rain for year 2002
# Downloading: rain for year 2003
# Downloading: rain for year 2004
# Downloading: rain for year 2005
# Downloading: rain for year 2006
# Downloading: rain for year 2007
# Downloading: rain for year 2008
# Downloading: rain for year 2009
# Downloading: rain for year 2010
# Downloading: rain for year 2011
# Downloading: rain for year 2012
# Downloading: rain for year 2013
# Downloading: rain for year 2014
# Downloading: rain for year 2015
# Downloading: rain for year 2016
# Downloading: rain for year 2017
# Downloading: rain for year 2018
# Downloading: rain for year 2019
# Download Successful !!!

# %%
ds = data.get_xarray() # Converting to xarray is also required for SLICING, for a date.

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 8400, lat: 129, lon: 135)
# Coordinates:
#   * lat      (lat) float64 6.5 6.75 7.0 7.25 7.5 ... 37.5 37.75 38.0 38.25 38.5
#   * lon      (lon) float64 66.5 66.75 67.0 67.25 67.5 ... 99.25 99.5 99.75 100.0
#   * time     (time) datetime64[ns] 1997-01-01 1997-01-02 ... 2019-12-31
# Data variables:
#     rain     (time, lat, lon) float64 -999.0 -999.0 -999.0 ... -999.0 -999.0
# Attributes:
#     Conventions:  CF-1.7
#     title:        IMD gridded data
#     source:       https://imdpune.gov.in/
#     history:      2023-05-27 07:35:52.461373 Python
#     references:
#     comment:
#     crs:          epsg:4326

# %%
d1 = ds.sel(time='1997-04-01')

# %%
d1
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 129, lon: 135)
# Coordinates:
#   * lat      (lat) float64 6.5 6.75 7.0 7.25 7.5 ... 37.5 37.75 38.0 38.25 38.5
#   * lon      (lon) float64 66.5 66.75 67.0 67.25 67.5 ... 99.25 99.5 99.75 100.0
#     time     datetime64[ns] 1997-04-01
# Data variables:
#     rain     (lat, lon) float64 -999.0 -999.0 -999.0 ... -999.0 -999.0 -999.0
# Attributes:
#     Conventions:  CF-1.7
#     title:        IMD gridded data
#     source:       https://imdpune.gov.in/
#     history:      2023-05-27 07:35:52.461373 Python
#     references:
#     comment:
#     crs:          epsg:4326

# %%
d2 = ds.sel(time='1997-04-02')
d2
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 129, lon: 135)
# Coordinates:
#   * lat      (lat) float64 6.5 6.75 7.0 7.25 7.5 ... 37.5 37.75 38.0 38.25 38.5
#   * lon      (lon) float64 66.5 66.75 67.0 67.25 67.5 ... 99.25 99.5 99.75 100.0
#     time     datetime64[ns] 1997-04-02
# Data variables:
#     rain     (lat, lon) float64 -999.0 -999.0 -999.0 ... -999.0 -999.0 -999.0
# Attributes:
#     Conventions:  CF-1.7
#     title:        IMD gridded data
#     source:       https://imdpune.gov.in/
#     history:      2023-05-27 07:35:52.461373 Python
#     references:
#     comment:
#     crs:          epsg:4326

# %%
avg_d = (d1 + d2)/2 # Average rain of 2 days
# Taking the average of 2 days data, similarly, we'll get the average for whole cultivation period

# %%
avg_d
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 129, lon: 135)
# Coordinates:
#   * lat      (lat) float64 6.5 6.75 7.0 7.25 7.5 ... 37.5 37.75 38.0 38.25 38.5
#   * lon      (lon) float64 66.5 66.75 67.0 67.25 67.5 ... 99.25 99.5 99.75 100.0
# Data variables:
#     rain     (lat, lon) float64 -999.0 -999.0 -999.0 ... -999.0 -999.0 -999.0

# %% [markdown]
# ## Using the `where` method of xarray

# %%
# agra_bdry =

# %%
from shapely.wkt import loads

# %%
# Getting a boolean mask file of the shapefile
agra_geom = loads(a_shape)  # Polygon
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-59cf77f59201> in <cell line: 2>()
#       1 # Getting a boolean mask file of the shapefile
# ----> 2 agra_geom = loads(a_shape)  # Polygon
#
# NameError: name 'a_shape' is not defined

# %%
# import rasterio.features

# %%
mask = rasterio.features.geometry_mask([agra_geom], out_shape=(data.latitude.size, data.longitude.size),
                                       transform=data.rio.transform(), invert=True)

# %%
masked_xarray = avg_d.where(agra_mask)

# %% [markdown]
# ## Rasterio.mask
# NOT USING THIS, -- INSTEAD use `where`

# %%
import rasterio.mask
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-26-d79dbc56f061> in <cell line: 1>()
# ----> 1 import rasterio.mask
#
# ModuleNotFoundError: No module named 'rasterio'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
a_shape = a_shape.to_crs(crs='EPSG:4326')

# %%
geom = a_shape.values[0]

# %%
shapes = gpd.GeoDataFrame({'geometry': [geom]})

# %%
masked_data, masked_transform = rasterio.mask.mask(avg_d.to_array(), shapes.geometry, nodata=-999, crop=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-77-50c457eb6840> in <cell line: 1>()
# ----> 1 masked_data, masked_transform = rasterio.mask.mask(avg_d.to_array(), shapes.geometry, nodata=-999, crop=True)
#
# /usr/local/lib/python3.9/dist-packages/rasterio/mask.py in mask(dataset, shapes, all_touched, invert, nodata, filled, crop, pad, pad_width, indexes)
#     176             nodata = 0
#     177
# --> 178     shape_mask, transform, window = raster_geometry_mask(
#     179         dataset, shapes, all_touched=all_touched, invert=invert, crop=crop,
#     180         pad=pad, pad_width=pad_width)
#
# /usr/local/lib/python3.9/dist-packages/rasterio/mask.py in raster_geometry_mask(dataset, shapes, all_touched, invert, crop, pad, pad_width)
#      78
#      79     try:
# ---> 80         window = geometry_window(dataset, shapes, pad_x=pad_x, pad_y=pad_y)
#      81
# ...

# %% [markdown]
# ## Rioxarray
# // NOT TO BE USED

# %%
pip install rioxarray
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.4/53.4 KB 2.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.1/20.1 MB 26.3 MB/s eta 0:00:00
# ...

# %%
import rioxarray

# %%
xds = rioxarray.open_rasterio(avg_d)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-58-777ccd00d835> in <cell line: 1>()
# ----> 1 xds = rioxarray.open_rasterio(avg_d)
#
# /usr/local/lib/python3.9/dist-packages/rioxarray/_io.py in open_rasterio(filename, parse_coordinates, chunks, cache, lock, masked, mask_and_scale, variable, group, default_name, decode_times, decode_timedelta, band_as_variable, **open_kwargs)
#    1116         else:
#    1117             manager = URIManager(file_opener, filename, mode="r", kwargs=open_kwargs)
# -> 1118         riods = manager.acquire()
#    1119         captured_warnings = rio_warnings.copy()
#    1120
#
# /usr/local/lib/python3.9/dist-packages/rioxarray/_io.py in acquire(self, needs_lock)
#     256                 self._opener, *self._args, mode=self._mode, kwargs=self._kwargs
#     257             )
# ...

# %%
mask = rasterio.features.geometry_mask(
            gdf.geometry,
            out_shape=ds.geobox.shape,
            transform=ds.geobox.affine,
            all_touched=False,
            invert=False)

# %%
mask = xr.DataArray(mask, dims=("y", "x"))

# %% [markdown]
# ## Yearly Data for Testing IMDLIB

# %%
start_yr = 2010
end_yr = 2018
variable = 'rain' # other options are ('tmin'/ 'tmax')
data = imd.get_data(variable, start_yr, end_yr, fn_format='yearwise')
# Out:
# Downloading: rain for year 2010
# Downloading: rain for year 2011
# Downloading: rain for year 2012
# Downloading: rain for year 2013
# Downloading: rain for year 2014
# Downloading: rain for year 2015
# Downloading: rain for year 2016
# Downloading: rain for year 2017
# Downloading: rain for year 2018
# Download Successful !!!

# %%
data

# %%
ds = data.get_xarray()

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 3287, lat: 129, lon: 135)
# Coordinates:
#   * lat      (lat) float64 6.5 6.75 7.0 7.25 7.5 ... 37.5 37.75 38.0 38.25 38.5
#   * lon      (lon) float64 66.5 66.75 67.0 67.25 67.5 ... 99.25 99.5 99.75 100.0
#   * time     (time) datetime64[ns] 2010-01-01 2010-01-02 ... 2018-12-31
# Data variables:
#     rain     (time, lat, lon) float64 -999.0 -999.0 -999.0 ... -999.0 -999.0
# Attributes:
#     Conventions:  CF-1.7
#     title:        IMD gridded data
#     source:       https://imdpune.gov.in/
#     history:      2023-04-09 17:20:31.548496 Python
#     references:
#     comment:
#     crs:          epsg:4326

# %% [markdown]
# ## LPK file:
#   But not required

# %%
ldf = gpd.read_file('/content/GIS_file_of_India_State,_District_and_Tehsil_Boundaries.lpk')
# Out:
# ERROR:fiona._env:`/content/GIS_file_of_India_State,_District_and_Tehsil_Boundaries.lpk' not recognized as a supported file format.
# ---------------------------------------------------------------------------
# CPLE_OpenFailedError                      Traceback (most recent call last)
# fiona/ogrext.pyx in fiona.ogrext.gdal_open_vector()
#
# fiona/_err.pyx in fiona._err.exc_wrap_pointer()
#
# CPLE_OpenFailedError: '/content/GIS_file_of_India_State,_District_and_Tehsil_Boundaries.lpk' not recognized as a supported file format.
#
# During handling of the above exception, another exception occurred:
#
# DriverError                               Traceback (most recent call last)
# <ipython-input-24-1efc81dc228b> in <cell line: 1>()
# ----> 1 ldf = gpd.read_file('/content/GIS_file_of_India_State,_District_and_Tehsil_Boundaries.lpk')
#
# /usr/local/lib/python3.9/dist-packages/geopandas/io/file.py in _read_file(filename, bbox, mask, rows, engine, **kwargs)
#     257
# ...
